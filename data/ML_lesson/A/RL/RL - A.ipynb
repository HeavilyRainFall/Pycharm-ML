# %%
import gymnasium as gym

# 创建环境（以CartPole为例）
env = gym.make("CartPole-v1", render_mode="rgb_array")

# 重置环境，获取初始状态
observation, info = env.reset()

for _ in range(1000):
    # 渲染环境（可视化）
    env.render()

    # 随机选择一个动作（在实际应用中，这里应该是你的智能体决策）
    action = env.action_space.sample()

    # 执行动作，获取下一步的状态、奖励、是否结束等信息
    observation, reward, terminated, truncated, info = env.step(action)

    # 如果游戏结束，提前终止
    if terminated or truncated:
        observation, info = env.reset()

# 关闭环境
env.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\pycharm jupyter git\.venv\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:258, in CartPoleEnv.render(self)
#     257 try:
# --> 258     import pygame
#     259     from pygame import gfxdraw
#
# ModuleNotFoundError: No module named 'pygame'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[18], line 11
#       7 observation, info = env.reset()
#       9 for _ in range(1000):
#      10     # 渲染环境（可视化）
# ---> 11     env.render()
#      13     # 随机选择一个动作（在实际应用中，这里应该是你的智能体决策）
#      14     action = env.action_space.sample()
#
# File D:\pycharm jupyter git\.venv\Lib\site-packages\gymnasium\core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File D:\pycharm jupyter git\.venv\Lib\site-packages\gymnasium\wrappers\common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File D:\pycharm jupyter git\.venv\Lib\site-packages\gymnasium\core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File D:\pycharm jupyter git\.venv\Lib\site-packages\gymnasium\wrappers\common.py:301, in PassiveEnvChecker.render(self)
#     299 if self.checked_render is False:
#     300     self.checked_render = True
# --> 301     return env_render_passive_checker(self.env)
#     302 else:
#     303     return self.env.render()
#
# File D:\pycharm jupyter git\.venv\Lib\site-packages\gymnasium\utils\passive_env_checker.py:361, in env_render_passive_checker(env)
#     355     else:
#     356         assert env.render_mode is None or env.render_mode in render_modes, (
#     357             "The environment was initialized successfully however with an unsupported render mode. "
#     358             f"Render mode: {env.render_mode}, modes: {render_modes}"
#     359         )
# --> 361 result = env.render()
#     362 if env.render_mode is not None:
#     363     _check_render_return(env.render_mode, result)
#
# File D:\pycharm jupyter git\.venv\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:261, in CartPoleEnv.render(self)
#     259     from pygame import gfxdraw
#     260 except ImportError as e:
# --> 261     raise DependencyNotInstalled(
#     262         'pygame is not installed, run `pip install "gymnasium[classic-control]"`'
#     263     ) from e
#     265 if self.screen is None:
#     266     pygame.init()
#
# DependencyNotInstalled: pygame is not installed, run `pip install "gymnasium[classic-control]"`

# %%
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26280\2682354064.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAPL']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26280\2682354064.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='bfill')

# %%
# Out:
# Empty DataFrame
# Columns: [(Close, AAPL), (MA5, ), (MA10, ), (Volume, AAPL)]
# Index: []
